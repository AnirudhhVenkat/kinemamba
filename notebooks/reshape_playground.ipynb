# %%
import sys
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn.functional as F

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
if str(ROOT / "src") not in sys.path:
    sys.path.insert(0, str(ROOT / "src"))

from models.cnn_encoder import CNNEncoder, normalize_image

EPISODE_NPZ = ROOT / "dataset_episodes/test/episode_0014_visuals.npz"
FRAME_IDX = 0

visuals = np.load(EPISODE_NPZ)["visuals"]
frame_hwc = visuals[FRAME_IDX]

print("episode file:", EPISODE_NPZ)
print("episode shape (T, H, W, C):", visuals.shape)
print("single frame shape (H, W, C):", frame_hwc.shape)
print("dtype / range:", frame_hwc.dtype, frame_hwc.min(), frame_hwc.max())

# %%
frame_hwc

# %%
model = CNNEncoder(image_size=(OUT_H, OUT_W))
encoded_image = model.forward(resized_chw)  # encoder normalizes uint8 internally
encoded_image.shape

# %%
encoded_image

# %%
import pandas as pd

df = pd.read_csv("/Users/anivenkat/kinemamba/dataset_episodes/test/episode_0014_data.csv")
df['obs_ttc'].hist()

# %%
df
